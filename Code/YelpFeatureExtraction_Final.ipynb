# %% [markdown]
# # The below code shows the extraction of more features in the YELP dataset

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import Series, DataFrame

# %matplotlib inline
pd.options.display.mpl_style = 'default'

pd.set_option('display.max_columns', 36)
print pd.__version__
# Out:
# 0.18.0

# %% [markdown]
# We will use NLTK to process and tokenize the data

# %%
import nltk
import string
from nltk import word_tokenize
from nltk.util import bigrams, trigrams
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from collections import Counter

# %%
# I have downloaded the required files for NLTK and we are doing preprocessing of data to perform a sentiment analysis later
POSITIVE_WORDS = set([line.strip() for line in open('positive-words.txt', 'r')])
NEGATIVE_WORDS = set([line.strip() for line in open('negative-words.txt', 'r')])
NLTK_STOPWORDS = set(stopwords.words('english'))
MORE_STOPWORDS = set([line.strip() for line in open('more_stopwords.txt', 'r')])

def remove_numbers_in_string(s):
    return s.translate(None, string.digits)

def lowercase_remove_punctuation(s):
    s = s.lower()
    s = s.translate(None, string.punctuation)
    return s
    
def remove_stopwords(s):
    token_list = nltk.word_tokenize(s)
    exclude_stopwords = lambda token : token not in NLTK_STOPWORDS
    return ' '.join(filter(exclude_stopwords, token_list))

def filter_out_more_stopwords(token_list):
    return filter(lambda tok : tok not in MORE_STOPWORDS, token_list)

def stem_token_list(token_list):
    STEMMER = PorterStemmer()
    return [STEMMER.stem(tok.decode('utf-8')) for tok in token_list]

def restring_tokens(token_list):
    return ' '.join(token_list)

def lowercase_remove_punctuation_and_numbers_and_tokenize_and_filter_more_stopwords_and_stem_and_restring(s):
    s = remove_numbers_in_string(s)
    s = lowercase_remove_punctuation(s)
    s = remove_stopwords(s)
    token_list = nltk.word_tokenize(s)
    token_list = filter_out_more_stopwords(token_list)
    token_list = stem_token_list(token_list)
    return restring_tokens(token_list)

# %%
turbo_csv_filename = os.path.join("./", 'TURBO_p2.csv')
TURBO_DF = pd.read_csv(turbo_csv_filename)

# %%
for idx in range(5):
    print TURBO_DF.review_text[idx]
    print
# Out:
# I think Zinc Brasserie will get better and better. I visited the restaurant only 6 days after they opened.
#
# The good:  The food is amazing.  I had a sandwich and dessert.  I can't remember what the sandwich was called but it was a pork sandwich. It was cooked to perfection.  Dessert was great too!  (Creme brûlée).
#
# The atmosphere is lovely!  Much more comfortable and elegant than other airport restaurants.
#
# The bad:  I noticed some issues with cleanliness (staff practices, dirty dish ware, dirty tables).  The staff also was somewhat unfriendly and borderline rude.
#
#
# Love love love Matt Carter concepts. The Mission, Zinc and House Brasserie are among some of my favorite restaurants.  I can't wait o try this location again and see how staff (and cleanliness) is settling in and improving.
#
# I've always heard this is one of the special places in Phoenix . . . but, I wasn't prepared for how much I would love it! Lots of seating, but still it feels cozy and comfortable. The kind of place you want to just sit and stay awhile. Food? Ah, yes . . . they have it . . . but with flare! Whoever is back in that kitchen has talent. Is there such a thing as "food talent?" Here there is for sure. Some folks call themselves "chefs," but, as we all know with one taste they really get bumped back into the "cook" category. Not at FEZ . . . this is a CHEF!
#
# My recommendation is to sit at the bar . . . enjoy meeting Sarah, one of the bartenders. Customer Service with a smile, red hair and PZAZZ!
#
# FEZ is definitely PZAZZ!
#
# In the Sunday, June 19th, AZ Republic they listed FEZ as one of the Top 10 Spots for "Yum on a Bun!"
#
# How could you not want to just jump on your tractor, in your Beemer, on your tricycle, in your 'YO' truck, on Hi Ho Silver, or whatever your mode of transport is and rush on down to Central Avenue for a juicy half-pound Angus beef burger? Add some cinnamon-spiced pear, feta cheese, crisp onions and a really wonderful BBQ sauce  . . . .ahhhh . . . mouth watering goodness!
#
# One of the Top 10? I don't think so . . . it is the TOP ONE!
#
# Back again! This time I was feeling like a light lunch. I wasn't sure FEZ really had small and tasty. Everything I have eaten here has been more than adequate in quantity and leftovers have always been a part of the meal.
#
# Well, today I just had a bowl of their 50/50 soup. Perfect size for a light lunch. With a little bread on the side. Couldn't have been better!  What is 50/50 soup? . . . I'll let you experience it for yourself. You will not be disappointed. Perfect for a cold winter day in the land of sunshine.
#
# CHOCOLATE DREAMS.
#
# Sometimes the very best things come from dreams. Julia Baker's dream was to make sure that the very best chocolate was available to everyone. Her dream was not a small one; nor one that was easily accomplished. But it was there and it was so real that it overshadowed the other successful parts of her life. How do I know this about her Chocolate Dream?
#
# Because she is not one to skimp on words. She tells it like it is. She lays it all out there for all to see. She tells a story that started with her dream and that story has grown into more than just one woman's dream; but has grown into the dream of many from Arizona to Ghana.
#
# That dream has become the reality of CHOCOLATE farming. Chocolate Confections. Chocolate Truffles. Chocolate Martinis. Chocolate Pralines. French Sipping Chocolate. Chocolate Mousse Cake. Red Velvet Chocolate Truffles. White Chocolate.  Milk Chocolate. Dark Chocolate. Chocolate Dreams. Chocolate. Sweet Chocolate. Sweet, Sweet Chocolate. This is what sweet dreams are made of . . . Sweet Julia with the chocolate dreams.
#
# www.JuliaBakerConfections.com

# %%
initial_features = ['business_id', 'business_name', 'review_stars', 'review_text','business_review_count']
df_with_initial_features_and_preprocessed_review_text = TURBO_DF[initial_features]
# %time df_with_initial_features_and_preprocessed_review_text['review_text'] = df_with_initial_features_and_preprocessed_review_text['review_text'].apply(lowercase_remove_punctuation_and_numbers_and_tokenize_and_filter_more_stopwords_and_stem_and_restring)

for idx in range(5):
    print df_with_initial_features_and_preprocessed_review_text.review_text[idx]
    print
# Out:
# Wall time: 28.4 s
# zinc brasseri visit restaur day open good food amaz sandwich dessert rememb sandwich call pork sandwich cook perfect dessert great creme brûlée atmospher love comfort eleg airport restaur bad notic issu cleanli staff practic dirti dish ware dirti tabl staff unfriendli borderlin rude love love love matt carter concept mission zinc hous brasseri favorit restaur wait locat staff cleanli settl improv
#
# ive heard special place phoenix wasnt prepar love lot seat feel cozi comfort kind place sit stay awhil food ah flare back kitchen talent thing food talent folk call chef tast bump back cook categori fez chef recommend sit bar enjoy meet sarah bartend custom servic smile red hair pzazz fez pzazz
#
# sunday june az republ list fez top spot yum bun jump tractor beemer tricycl yo truck ho silver mode transport rush central avenu juici halfpound angu beef burger add cinnamonsp pear feta chees crisp onion wonder bbq sauc ahhhh mouth water good top dont top
#
# back time feel light lunch wasnt fez small tasti eaten adequ quantiti leftov part meal today bowl soup perfect size light lunch bread side couldnt soup ill experi disappoint perfect cold winter day land sunshin
#
# chocol dream thing dream julia baker dream make chocol dream small easili accomplish real overshadow success part life chocol dream skimp word tell lay tell stori start dream stori grown woman dream grown dream arizona ghana dream realiti chocol farm chocol confect chocol truffl chocol martini chocol pralin french sip chocol chocol mouss cake red velvet chocol truffl white chocol milk chocol dark chocol chocol dream chocol sweet chocol sweet sweet chocol sweet dream made sweet julia chocol dream wwwjuliabakerconfectionscom
# C:\Users\kritz\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
from sklearn.cross_validation import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.naive_bayes import *
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report, precision_score, recall_score, roc_auc_score

# %%
import json
from collections import OrderedDict
 
def convert_json_dict_string_to_python_dict(json_string_dict):
    return json.loads(json_string_dict.replace('\'', '"').replace('u"', '"'))

def get_number_of_review_votes_that_are(cool_or_funny_or_useful):
    assert cool_or_funny_or_useful in ['cool', 'funny', 'useful']
    return lambda review_votes_dict : review_votes_dict[cool_or_funny_or_useful]

def get_total_review_votes(review_votes_dict):
    return review_votes_dict['cool'] + review_votes_dict['funny'] + review_votes_dict['useful']

def get_number_of_compliments_that_are(cool_or_cute_or_funny_or_hot_or_list_or_more_or_note_or_photos_or_plain_or_profile_or_writer):
    key = cool_or_cute_or_funny_or_hot_or_list_or_more_or_note_or_photos_or_plain_or_profile_or_writer
    assert cool_or_cute_or_funny_or_hot_or_list_or_more_or_note_or_photos_or_plain_or_profile_or_writer in [u'cool',
                                                                                                            u'cute',
                                                                                                            u'funny',
                                                                                                            u'hot',
                                                                                                            u'list',
                                                                                                            u'more',
                                                                                                            u'note',
                                                                                                            u'photos',
                                                                                                            u'plain',
                                                                                                            u'profile',
                                                                                                            u'writer']
    return lambda compliments_dict : compliments_dict[key] if key in compliments_dict else 0

def count_number_of_positive_words(document):
    return len(filter(lambda tok : tok in POSITIVE_WORDS, document.split()))

def count_number_of_negative_words(document):
    return len(filter(lambda tok : tok in NEGATIVE_WORDS, document.split()))

def check_that_userid_does_not_appear_in_its_friendid_list(df):
    for i, x in df.iterrows():
        d = OrderedDict(x)
        assert d['business_id'] not in d['friends_id_list']

def get_average_friends_average_stars(df):
    
    def apply_func(friend_user_id_list):
        friend_ids_that_exist_in_df = set(df['user_id']).intersection(set(friend_user_id_list))
        indices_of_records_with_friend_ids = df['user_id'].isin(friend_ids_that_exist_in_df)
        userid_and_averagestars_df = df[['user_id', 'user_average_stars']]
        friends_average_stars_indexed_by_userid_df = userid_and_averagestars_df.loc[indices_of_records_with_friend_ids].groupby('user_id').mean()
        return np.mean(friends_average_stars_indexed_by_userid_df['user_average_stars'])
    
    return apply_func

# %%
#The below code generates most of the subset of features mentioned in the report to be used later for prediction.

df_with_refeature_engineered = df_with_initial_features_and_preprocessed_review_text
df_with_refeature_engineered['review_votes'] = TURBO_DF.review_votes.apply(convert_json_dict_string_to_python_dict)
df_with_refeature_engineered['review_cool'] = df_with_refeature_engineered.review_votes.apply(get_number_of_review_votes_that_are('cool'))
df_with_refeature_engineered['review_funny'] = df_with_refeature_engineered.review_votes.apply(get_number_of_review_votes_that_are('funny'))
df_with_refeature_engineered['review_useful'] = df_with_refeature_engineered.review_votes.apply(get_number_of_review_votes_that_are('useful'))
df_with_refeature_engineered['review_votes_count'] = df_with_refeature_engineered.review_votes.apply(get_total_review_votes)
df_with_refeature_engineered['review_length'] = df_with_refeature_engineered.review_text.apply(len)

df_with_refeature_engineered['user_id'] = TURBO_DF.user_id
df_with_refeature_engineered['user_votes'] = TURBO_DF.user_votes.apply(convert_json_dict_string_to_python_dict)
df_with_refeature_engineered['user_cool'] = df_with_refeature_engineered.user_votes.apply(get_number_of_review_votes_that_are('cool'))
df_with_refeature_engineered['user_funny'] = df_with_refeature_engineered.user_votes.apply(get_number_of_review_votes_that_are('funny'))
df_with_refeature_engineered['user_useful'] = df_with_refeature_engineered.user_votes.apply(get_number_of_review_votes_that_are('useful'))
df_with_refeature_engineered['user_votes_count'] = df_with_refeature_engineered.user_votes.apply(get_total_review_votes)
df_with_refeature_engineered['user_review_count'] = TURBO_DF.user_review_count
df_with_refeature_engineered['user_fans'] = TURBO_DF.fans
df_with_refeature_engineered['user_friends_count'] = TURBO_DF.friends.apply(len)
df_with_refeature_engineered['user_years_elite_count'] = TURBO_DF.elite.apply(len)
df_with_refeature_engineered['user_compliments'] = TURBO_DF.compliments.apply(convert_json_dict_string_to_python_dict)
df_with_refeature_engineered['user_compliments_cool'] = df_with_refeature_engineered.user_compliments.apply(get_number_of_compliments_that_are('cool'))
df_with_refeature_engineered['user_compliments_cute'] = df_with_refeature_engineered.user_compliments.apply(get_number_of_compliments_that_are('cute'))
df_with_refeature_engineered['user_compliments_funny'] = df_with_refeature_engineered.user_compliments.apply(get_number_of_compliments_that_are('funny'))
df_with_refeature_engineered['user_compliments_hot'] = df_with_refeature_engineered.user_compliments.apply(get_number_of_compliments_that_are('hot'))
df_with_refeature_engineered['user_compliments_list'] = df_with_refeature_engineered.user_compliments.apply(get_number_of_compliments_that_are('list'))
df_with_refeature_engineered['user_compliments_more'] = df_with_refeature_engineered.user_compliments.apply(get_number_of_compliments_that_are('more'))
df_with_refeature_engineered['user_compliments_note'] = df_with_refeature_engineered.user_compliments.apply(get_number_of_compliments_that_are('note'))
df_with_refeature_engineered['user_compliments_photos'] = df_with_refeature_engineered.user_compliments.apply(get_number_of_compliments_that_are('photos'))
df_with_refeature_engineered['user_compliments_plain'] = df_with_refeature_engineered.user_compliments.apply(get_number_of_compliments_that_are('plain'))
df_with_refeature_engineered['user_compliments_profile'] = df_with_refeature_engineered.user_compliments.apply(get_number_of_compliments_that_are('profile'))
df_with_refeature_engineered['user_compliments_writer'] = df_with_refeature_engineered.user_compliments.apply(get_number_of_compliments_that_are('writer'))

df_with_refeature_engineered['user_average_stars'] = TURBO_DF.average_stars
df_with_refeature_engineered['business_stars'] = TURBO_DF.business_stars

df_with_refeature_engineered['positive_words_count'] = TURBO_DF.review_text.apply(count_number_of_positive_words)
df_with_refeature_engineered['negative_words_count'] = TURBO_DF.review_text.apply(count_number_of_negative_words)
df_with_refeature_engineered['neutral_words_count'] = df_with_refeature_engineered.review_length - (df_with_refeature_engineered.positive_words_count + df_with_refeature_engineered.negative_words_count)
df_with_refeature_engineered['positive_words_count_over_review_length'] = df_with_refeature_engineered.positive_words_count / (1.0*df_with_refeature_engineered.review_length)
df_with_refeature_engineered['negative_words_count_over_review_length'] = df_with_refeature_engineered.negative_words_count / (1.0*df_with_refeature_engineered.review_length)
df_with_refeature_engineered['neutral_words_count_over_review_length'] = df_with_refeature_engineered.neutral_words_count / (1.0*df_with_refeature_engineered.review_length)
df_with_refeature_engineered['positive_to_negative_words_count_ratio'] = df_with_refeature_engineered.positive_words_count / (1.0*df_with_refeature_engineered.negative_words_count)
df_with_refeature_engineered['negative_to_positive_words_count_ratio'] = df_with_refeature_engineered.negative_words_count / (1.0*df_with_refeature_engineered.positive_words_count)

df_with_refeature_engineered['friends_id_list'] = TURBO_DF.friends.apply(lambda s : s.replace('[', '').replace(']','').split(', '))
check_that_userid_does_not_appear_in_its_friendid_list(df_with_refeature_engineered)
df_with_refeature_engineered['friends_average_stars'] = df_with_refeature_engineered.friends_id_list.apply(get_average_friends_average_stars(df_with_refeature_engineered))
# Out:
# C:\Users\kritz\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\kritz\Anaconda2\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\kritz\Anaconda2\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\kritz\Anaconda2\lib\site-packages\ipykernel\__main__.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\kritz\Anaconda2\lib\site-packages\ipykernel\__main__.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\kritz\Anaconda2\lib\site-packages\ipykernel\__main__.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\kritz\Anaconda2\lib\site-packages\ipykernel\__main__.py:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\kritz\Anaconda2\lib\site-packages\ipykernel\__main__.py:10: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\kritz\Anaconda2\lib\site-packages\ipykernel\__main__.py:11: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\kritz\Anaconda2\lib\site-packages\ipykernel\__main__.py:12: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\kritz\Anaconda2\lib\site-packages\ipykernel\__main__.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\kritz\Anaconda2\lib\site-packages\ipykernel\__main__.py:14: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\kritz\Anaconda2\lib\site-packages\ipykernel\__main__.py:15: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\kritz\Anaconda2\lib\site-packages\ipykernel\__main__.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\kritz\Anaconda2\lib\site-packages\ipykernel\__main__.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\kritz\Anaconda2\lib\site-packages\ipykernel\__main__.py:18: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\kritz\Anaconda2\lib\site-packages\ipykernel\__main__.py:19: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\kritz\Anaconda2\lib\site-packages\ipykernel\__main__.py:20: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\kritz\Anaconda2\lib\site-packages\ipykernel\__main__.py:21: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\kritz\Anaconda2\lib\site-packages\ipykernel\__main__.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\kritz\Anaconda2\lib\site-packages\ipykernel\__main__.py:23: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\kritz\Anaconda2\lib\site-packages\ipykernel\__main__.py:24: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\kritz\Anaconda2\lib\site-packages\ipykernel\__main__.py:25: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\kritz\Anaconda2\lib\site-packages\ipykernel\__main__.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\kritz\Anaconda2\lib\site-packages\ipykernel\__main__.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\kritz\Anaconda2\lib\site-packages\ipykernel\__main__.py:28: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\kritz\Anaconda2\lib\site-packages\ipykernel\__main__.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\kritz\Anaconda2\lib\site-packages\ipykernel\__main__.py:30: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\kritz\Anaconda2\lib\site-packages\ipykernel\__main__.py:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\kritz\Anaconda2\lib\site-packages\ipykernel\__main__.py:33: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\kritz\Anaconda2\lib\site-packages\ipykernel\__main__.py:35: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\kritz\Anaconda2\lib\site-packages\ipykernel\__main__.py:36: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\kritz\Anaconda2\lib\site-packages\ipykernel\__main__.py:37: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_with_refeature_engineered.to_csv("turbo_with_generated_features.csv", encoding='utf-8')

# %%
# I have taken the above file and generated more features like number of businesses within 1km in R and 
#also feautures with respect to reviews in excel and R and generated another document called turbo_predict.csv
#containing the unique business ids with all their feature vectors which will be use later for prediction.

# %%
turbo_csv_filename = os.path.join("./", 'turbo_predict.csv')
df_with_refeature_engineered = pd.read_csv(turbo_csv_filename)

# %%
corr_features = ['review_cool', 'review_funny', 'review_useful', 'review_votes_count', 'review_length',
                'Average_number_of_stars','Max_Number_of_stars','Min_Number_of_stars','business_review_count',
 'user_cool', 'user_funny', 'user_useful', 'user_votes_count', 'user_review_count', 'user_fans',
                 'user_friends_count', 'user_years_elite_count', 'user_compliments_cool', 'user_compliments_cool',
                 'user_compliments_cute', 'user_compliments_funny', 'user_compliments_hot', 'user_compliments_list',
                 'user_compliments_more', 'user_compliments_note', 'user_compliments_photos', 'user_compliments_plain',
                 'user_compliments_profile', 'user_compliments_writer',
                 'positive_words_count', 'negative_words_count', 'positive_to_negative_words_count_ratio',
                 'negative_to_positive_words_count_ratio', 'neutral_words_count', 'neutral_words_count_over_review_length',
                 'positive_words_count_over_review_length', 'negative_words_count_over_review_length', 'friends_average_stars',              
                 'user_average_stars', 'business_stars', 'review_stars','business_review_count']
Corr_df = df_with_refeature_engineered[corr_features].corr()
Corr_df
# Out:
#                                          review_cool  review_funny  \
# review_cool                                 1.000000      0.846001
# review_funny                                0.846001      1.000000
# review_useful                               0.884791      0.799753
# review_votes_count                          0.961694      0.916352
# review_length                               0.375141      0.323274
# Average_number_of_stars                     0.071370     -0.008216
# Max_Number_of_stars                         0.123804      0.040158
# Min_Number_of_stars                        -0.108937     -0.132546
# business_review_count                       0.260300      0.200262
# user_cool                                   0.457695      0.369084
# user_funny                                  0.438596      0.375682
# user_useful                                 0.453992      0.365082
# user_votes_count                            0.453661      0.370778
# user_review_count                           0.327480      0.253968
# user_fans                                   0.462639      0.352330
# user_friends_count                          0.456759      0.391286
# user_years_elite_count                      0.441711      0.372813
# user_compliments_cool                       0.344579      0.284697
# user_compliments_cool                       0.344579      0.284697
# user_compliments_cute                       0.447224      0.342279
# user_compliments_funny                      0.270635      0.236144
# user_compliments_hot                        0.384479      0.319078
# user_compliments_list                       0.384801      0.309770
# user_compliments_more                       0.286198      0.239378
# user_compliments_note                       0.460281      0.369216
# user_compliments_photos                     0.218095      0.173325
# user_compliments_plain                      0.412474      0.333361
# user_compliments_profile                    0.253006      0.209818
# user_compliments_writer                     0.286627      0.239103
# positive_words_count                        0.369199      0.299277
# negative_words_count                        0.223213      0.250177
# positive_to_negative_words_count_ratio      0.192742      0.080743
# negative_to_positive_words_count_ratio      0.000161      0.071790
# neutral_words_count                         0.374630      0.322778
# neutral_words_count_over_review_length      0.055881      0.058426
# positive_words_count_over_review_length    -0.044928     -0.078578
# negative_words_count_over_review_length    -0.028273      0.029718
# friends_average_stars                      -0.152963     -0.130840
# user_average_stars                          0.070254      0.024403
# business_stars                              0.131946      0.062032
# review_stars                                0.097869     -0.012682
# business_review_count                       0.260300      0.200262
#
#                                          review_useful  review_votes_count  \
# review_cool                                   0.884791            0.961694
# review_funny                                  0.799753            0.916352
# review_useful                                 1.000000            0.958301
# review_votes_count                            0.958301            1.000000
# review_length                                 0.400863            0.391924
# Average_number_of_stars                       0.044185            0.041018
# Max_Number_of_stars                           0.107005            0.099608
# Min_Number_of_stars                          -0.129908           -0.130582
# business_review_count                         0.242205            0.249739
# user_cool                                     0.429709            0.445585
# user_funny                                    0.408833            0.431990
# user_useful                                   0.431812            0.444077
# user_votes_count                              0.427573            0.443771
# user_review_count                             0.314926            0.319133
# user_fans                                     0.450322            0.451328
# user_friends_count                            0.453445            0.461727
# user_years_elite_count                        0.435386            0.443594
# user_compliments_cool                         0.308505            0.330990
# user_compliments_cool                         0.308505            0.330990
# user_compliments_cute                         0.400558            0.421909
# user_compliments_funny                        0.252919            0.268068
# user_compliments_hot                          0.346309            0.370608
# user_compliments_list                         0.350003            0.369651
# user_compliments_more                         0.253808            0.274703
# user_compliments_note                         0.434563            0.448585
# user_compliments_photos                       0.198768            0.209039
# user_compliments_plain                        0.390290            0.403070
# user_compliments_profile                      0.225169            0.242673
# user_compliments_writer                       0.255488            0.275490
# positive_words_count                          0.379657            0.373996
# negative_words_count                          0.253977            0.256256
# positive_to_negative_words_count_ratio        0.190784            0.169326
# negative_to_positive_words_count_ratio        0.036146            0.035842
# neutral_words_count                           0.400470            0.391440
# neutral_words_count_over_review_length        0.079265            0.069662
# positive_words_count_over_review_length      -0.075135           -0.069873
# negative_words_count_over_review_length      -0.018710           -0.009238
# friends_average_stars                        -0.148305           -0.153045
# user_average_stars                            0.073928            0.062629
# business_stars                                0.118063            0.113349
# review_stars                                  0.039947            0.047020
# business_review_count                         0.242205            0.249739
#
#                                          review_length  \
# review_cool                                   0.375141
# review_funny                                  0.323274
# review_useful                                 0.400863
# review_votes_count                            0.391924
# review_length                                 1.000000
# Average_number_of_stars                       0.043213
# Max_Number_of_stars                           0.083062
# Min_Number_of_stars                          -0.115795
# business_review_count                         0.295686
# user_cool                                     0.322483
# user_funny                                    0.309742
# user_useful                                   0.341593
# user_votes_count                              0.329049
# user_review_count                             0.362562
# user_fans                                     0.341570
# user_friends_count                            0.349620
# user_years_elite_count                        0.356094
# user_compliments_cool                         0.219689
# user_compliments_cool                         0.219689
# user_compliments_cute                         0.221177
# user_compliments_funny                        0.144064
# user_compliments_hot                          0.219663
# user_compliments_list                         0.273203
# user_compliments_more                         0.212136
# user_compliments_note                         0.262135
# user_compliments_photos                       0.184791
# user_compliments_plain                        0.233808
# user_compliments_profile                      0.158937
# user_compliments_writer                       0.242313
# positive_words_count                          0.867083
# negative_words_count                          0.699071
# positive_to_negative_words_count_ratio        0.258427
# negative_to_positive_words_count_ratio        0.067303
# neutral_words_count                           0.999958
# neutral_words_count_over_review_length        0.149039
# positive_words_count_over_review_length      -0.150147
# negative_words_count_over_review_length      -0.018534
# friends_average_stars                        -0.089188
# user_average_stars                            0.024058
# business_stars                                0.111711
# review_stars                                  0.013344
# business_review_count                         0.295686
#
#                                          Average_number_of_stars  \
# review_cool                                             0.071370
# review_funny                                           -0.008216
# review_useful                                           0.044185
# review_votes_count                                      0.041018
# review_length                                           0.043213
# Average_number_of_stars                                 1.000000
# Max_Number_of_stars                                     0.821639
# Min_Number_of_stars                                     0.664573
# business_review_count                                   0.158661
# user_cool                                               0.010931
# user_funny                                              0.006924
# user_useful                                             0.008090
# user_votes_count                                        0.008796
# user_review_count                                       0.021664
# user_fans                                               0.013630
# user_friends_count                                      0.019108
# user_years_elite_count                                  0.048362
# user_compliments_cool                                  -0.004340
# user_compliments_cool                                  -0.004340
# user_compliments_cute                                   0.002463
# user_compliments_funny                                 -0.023958
# user_compliments_hot                                    0.000298
# user_compliments_list                                  -0.001757
# user_compliments_more                                  -0.000534
# user_compliments_note                                  -0.003984
# user_compliments_photos                                -0.012195
# user_compliments_plain                                 -0.012495
# user_compliments_profile                               -0.009345
# user_compliments_writer                                 0.001372
# positive_words_count                                    0.126813
# negative_words_count                                   -0.118574
# positive_to_negative_words_count_ratio                  0.243656
# negative_to_positive_words_count_ratio                 -0.277126
# neutral_words_count                                     0.042655
# neutral_words_count_over_review_length                 -0.070786
# positive_words_count_over_review_length                 0.190651
# negative_words_count_over_review_length                -0.215034
# friends_average_stars                                   0.032144
# user_average_stars                                      0.367632
# business_stars                                          0.618731
# review_stars                                            0.762887
# business_review_count                                   0.158661
#
#                                          Max_Number_of_stars  \
# review_cool                                         0.123804
# review_funny                                        0.040158
# review_useful                                       0.107005
# review_votes_count                                  0.099608
# review_length                                       0.083062
# Average_number_of_stars                             0.821639
# Max_Number_of_stars                                 1.000000
# Min_Number_of_stars                                 0.249202
# business_review_count                               0.257470
# user_cool                                           0.070379
# user_funny                                          0.065034
# user_useful                                         0.074952
# user_votes_count                                    0.071356
# user_review_count                                   0.113060
# user_fans                                           0.077755
# user_friends_count                                  0.139980
# user_years_elite_count                              0.155646
# user_compliments_cool                               0.037519
# user_compliments_cool                               0.037519
# user_compliments_cute                               0.054248
# user_compliments_funny                              0.026771
# user_compliments_hot                                0.046597
# user_compliments_list                               0.049683
# user_compliments_more                               0.036398
# user_compliments_note                               0.062054
# user_compliments_photos                             0.018515
# user_compliments_plain                              0.040836
# user_compliments_profile                            0.025322
# user_compliments_writer                             0.036279
# positive_words_count                                0.162385
# negative_words_count                               -0.072308
# positive_to_negative_words_count_ratio              0.242063
# negative_to_positive_words_count_ratio             -0.237588
# neutral_words_count                                 0.082366
# neutral_words_count_over_review_length             -0.055428
# positive_words_count_over_review_length             0.159011
# negative_words_count_over_review_length            -0.186619
# friends_average_stars                               0.006968
# user_average_stars                                  0.353233
# business_stars                                      0.528571
# review_stars                                        0.657287
# business_review_count                               0.257470
#
#                                          Min_Number_of_stars  \
# review_cool                                        -0.108937
# review_funny                                       -0.132546
# review_useful                                      -0.129908
# review_votes_count                                 -0.130582
# review_length                                      -0.115795
# Average_number_of_stars                             0.664573
# Max_Number_of_stars                                 0.249202
# Min_Number_of_stars                                 1.000000
# business_review_count                              -0.309002
# user_cool                                          -0.126258
# user_funny                                         -0.123508
# user_useful                                        -0.138773
# user_votes_count                                   -0.131516
# user_review_count                                  -0.177036
# user_fans                                          -0.130015
# user_friends_count                                 -0.196867
# user_years_elite_count                             -0.181759
# user_compliments_cool                              -0.082008
# user_compliments_cool                              -0.082008
# user_compliments_cute                              -0.087908
# user_compliments_funny                             -0.078286
# user_compliments_hot                               -0.085941
# user_compliments_list                              -0.103374
# user_compliments_more                              -0.068571
# user_compliments_note                              -0.120209
# user_compliments_photos                            -0.062848
# user_compliments_plain                             -0.103192
# user_compliments_profile                           -0.065966
# user_compliments_writer                            -0.075720
# positive_words_count                               -0.055569
# negative_words_count                               -0.175260
# positive_to_negative_words_count_ratio              0.087939
# negative_to_positive_words_count_ratio             -0.181357
# neutral_words_count                                -0.115941
# neutral_words_count_over_review_length             -0.074720
# positive_words_count_over_review_length             0.156609
# negative_words_count_over_review_length            -0.143262
# friends_average_stars                               0.052142
# user_average_stars                                  0.214197
# business_stars                                      0.304832
# review_stars                                        0.489759
# business_review_count                              -0.309002
#
#                                          business_review_count  user_cool  \
# review_cool                                           0.260300   0.457695
# review_funny                                          0.200262   0.369084
# review_useful                                         0.242205   0.429709
# review_votes_count                                    0.249739   0.445585
# review_length                                         0.295686   0.322483
# Average_number_of_stars                               0.158661   0.010931
# Max_Number_of_stars                                   0.257470   0.070379
# Min_Number_of_stars                                  -0.309002  -0.126258
# business_review_count                                 1.000000   0.261979
# user_cool                                             0.261979   1.000000
# user_funny                                            0.241647   0.983902
# user_useful                                           0.275296   0.993545
# user_votes_count                                      0.263934   0.998148
# user_review_count                                     0.306554   0.784634
# user_fans                                             0.289260   0.890826
# user_friends_count                                    0.257973   0.378545
# user_years_elite_count                                0.309313   0.471614
# user_compliments_cool                                 0.171153   0.850486
# user_compliments_cool                                 0.171153   0.850486
# user_compliments_cute                                 0.202183   0.818718
# user_compliments_funny                                0.104055   0.602545
# user_compliments_hot                                  0.176225   0.843763
# user_compliments_list                                 0.223489   0.925160
# user_compliments_more                                 0.152090   0.813856
# user_compliments_note                                 0.222637   0.907203
# user_compliments_photos                               0.122695   0.747540
# user_compliments_plain                                0.192502   0.904779
# user_compliments_profile                              0.123641   0.759746
# user_compliments_writer                               0.176549   0.839574
# positive_words_count                                  0.289852   0.300945
# negative_words_count                                  0.183558   0.187617
# positive_to_negative_words_count_ratio                0.136236   0.147370
# negative_to_positive_words_count_ratio               -0.030898   0.010155
# neutral_words_count                                   0.295253   0.322351
# neutral_words_count_over_review_length                0.041386   0.060428
# positive_words_count_over_review_length              -0.019918  -0.053121
# negative_words_count_over_review_length              -0.045991  -0.022063
# friends_average_stars                                -0.066273  -0.185319
# user_average_stars                                    0.063584   0.022600
# business_stars                                        0.262762   0.044427
# review_stars                                          0.119913   0.015167
# business_review_count                                 1.000000   0.261979
#
#                                          user_funny  user_useful  \
# review_cool                                0.438596     0.453992
# review_funny                               0.375682     0.365082
# review_useful                              0.408833     0.431812
# review_votes_count                         0.431990     0.444077
# review_length                              0.309742     0.341593
# Average_number_of_stars                    0.006924     0.008090
# Max_Number_of_stars                        0.065034     0.074952
# Min_Number_of_stars                       -0.123508    -0.138773
# business_review_count                      0.241647     0.275296
# user_cool                                  0.983902     0.993545
# user_funny                                 1.000000     0.974978
# user_useful                                0.974978     1.000000
# user_votes_count                           0.988796     0.996546
# user_review_count                          0.766814     0.828451
# user_fans                                  0.825185     0.908736
# user_friends_count                         0.375955     0.411086
# user_years_elite_count                     0.459075     0.499331
# user_compliments_cool                      0.863523     0.812921
# user_compliments_cool                      0.863523     0.812921
# user_compliments_cute                      0.757677     0.792125
# user_compliments_funny                     0.606234     0.590519
# user_compliments_hot                       0.851762     0.802624
# user_compliments_list                      0.907953     0.910490
# user_compliments_more                      0.839432     0.779937
# user_compliments_note                      0.880693     0.889490
# user_compliments_photos                    0.766709     0.715266
# user_compliments_plain                     0.889784     0.878924
# user_compliments_profile                   0.785746     0.718550
# user_compliments_writer                    0.864100     0.808947
# positive_words_count                       0.291611     0.312093
# negative_words_count                       0.195644     0.204965
# positive_to_negative_words_count_ratio     0.122891     0.148075
# negative_to_positive_words_count_ratio     0.021741     0.016029
# neutral_words_count                        0.309471     0.341528
# neutral_words_count_over_review_length     0.056341     0.065026
# positive_words_count_over_review_length   -0.053546    -0.058958
# negative_words_count_over_review_length   -0.013034    -0.020375
# friends_average_stars                     -0.180483    -0.196971
# user_average_stars                         0.002368     0.022457
# business_stars                             0.038402     0.045260
# review_stars                               0.008217     0.012630
# business_review_count                      0.241647     0.275296
#
#                                          user_votes_count  user_review_count  \
# review_cool                                      0.453661           0.327480
# review_funny                                     0.370778           0.253968
# review_useful                                    0.427573           0.314926
# review_votes_count                               0.443771           0.319133
# review_length                                    0.329049           0.362562
# Average_number_of_stars                          0.008796           0.021664
# Max_Number_of_stars                              0.071356           0.113060
# Min_Number_of_stars                             -0.131516          -0.177036
# business_review_count                            0.263934           0.306554
# user_cool                                        0.998148           0.784634
# user_funny                                       0.988796           0.766814
# user_useful                                      0.996546           0.828451
# user_votes_count                                 1.000000           0.802694
# user_review_count                                0.802694           1.000000
# user_fans                                        0.886690           0.730407
# user_friends_count                               0.393574           0.531689
# user_years_elite_count                           0.482608           0.573155
# user_compliments_cool                            0.841810           0.497476
# user_compliments_cool                            0.841810           0.497476
# user_compliments_cute                            0.796439           0.499468
# user_compliments_funny                           0.601244           0.404945
# user_compliments_hot                             0.832303           0.483349
# user_compliments_list                            0.919183           0.646680
# user_compliments_more                            0.809620           0.502192
# user_compliments_note                            0.897571           0.607052
# user_compliments_photos                          0.742116           0.467395
# user_compliments_plain                           0.894489           0.545236
# user_compliments_profile                         0.752258           0.416129
# user_compliments_writer                          0.836605           0.535688
# positive_words_count                             0.304855           0.307125
# negative_words_count                             0.197862           0.222453
# positive_to_negative_words_count_ratio           0.142355           0.132566
# negative_to_positive_words_count_ratio           0.015534           0.007975
# neutral_words_count                              0.328911           0.362872
# neutral_words_count_over_review_length           0.061675           0.089047
# positive_words_count_over_review_length         -0.055963          -0.078368
# negative_words_count_over_review_length         -0.019244          -0.032346
# friends_average_stars                           -0.189985          -0.209354
# user_average_stars                               0.017701           0.034451
# business_stars                                   0.043522           0.058681
# review_stars                                     0.012462           0.017015
# business_review_count                            0.263934           0.306554
#
#                                          user_fans  user_friends_count  \
# review_cool                               0.462639            0.456759
# review_funny                              0.352330            0.391286
# review_useful                             0.450322            0.453445
# review_votes_count                        0.451328            0.461727
# review_length                             0.341570            0.349620
# Average_number_of_stars                   0.013630            0.019108
# Max_Number_of_stars                       0.077755            0.139980
# Min_Number_of_stars                      -0.130015           -0.196867
# business_review_count                     0.289260            0.257973
# user_cool                                 0.890826            0.378545
# user_funny                                0.825185            0.375955
# user_useful                               0.908736            0.411086
# user_votes_count                          0.886690            0.393574
# user_review_count                         0.730407            0.531689
# user_fans                                 1.000000            0.376920
# user_friends_count                        0.376920            1.000000
# user_years_elite_count                    0.461079            0.714624
# user_compliments_cool                     0.632782            0.246876
# user_compliments_cool                     0.632782            0.246876
# user_compliments_cute                     0.804245            0.274050
# user_compliments_funny                    0.457028            0.220985
# user_compliments_hot                      0.627460            0.277847
# user_compliments_list                     0.810901            0.277597
# user_compliments_more                     0.577274            0.220907
# user_compliments_note                     0.799599            0.338033
# user_compliments_photos                   0.477749            0.156160
# user_compliments_plain                    0.767576            0.274092
# user_compliments_profile                  0.499537            0.159230
# user_compliments_writer                   0.623213            0.214008
# positive_words_count                      0.304967            0.326030
# negative_words_count                      0.204602            0.224402
# positive_to_negative_words_count_ratio    0.163348            0.219625
# negative_to_positive_words_count_ratio    0.018747            0.021716
# neutral_words_count                       0.341628            0.349345
# neutral_words_count_over_review_length    0.059053            0.070548
# positive_words_count_over_review_length  -0.054783           -0.060555
# negative_words_count_over_review_length  -0.016177           -0.028501
# friends_average_stars                    -0.180596           -0.198436
# user_average_stars                        0.058185            0.101001
# business_stars                            0.054734            0.063830
# review_stars                              0.021547            0.000252
# business_review_count                     0.289260            0.257973
#
#                                          user_years_elite_count  \
# review_cool                                            0.441711
# review_funny                                           0.372813
# review_useful                                          0.435386
# review_votes_count                                     0.443594
# review_length                                          0.356094
# Average_number_of_stars                                0.048362
# Max_Number_of_stars                                    0.155646
# Min_Number_of_stars                                   -0.181759
# business_review_count                                  0.309313
# user_cool                                              0.471614
# user_funny                                             0.459075
# user_useful                                            0.499331
# user_votes_count                                       0.482608
# user_review_count                                      0.573155
# user_fans                                              0.461079
# user_friends_count                                     0.714624
# user_years_elite_count                                 1.000000
# user_compliments_cool                                  0.312127
# user_compliments_cool                                  0.312127
# user_compliments_cute                                  0.391292
# user_compliments_funny                                 0.279148
# user_compliments_hot                                   0.355633
# user_compliments_list                                  0.380731
# user_compliments_more                                  0.279266
# user_compliments_note                                  0.420638
# user_compliments_photos                                0.180212
# user_compliments_plain                                 0.344570
# user_compliments_profile                               0.211475
# user_compliments_writer                                0.269380
# positive_words_count                                   0.312862
# negative_words_count                                   0.222662
# positive_to_negative_words_count_ratio                 0.189127
# negative_to_positive_words_count_ratio                 0.041777
# neutral_words_count                                    0.356180
# neutral_words_count_over_review_length                 0.113025
# positive_words_count_over_review_length               -0.106155
# negative_words_count_over_review_length               -0.028519
# friends_average_stars                                 -0.199851
# user_average_stars                                     0.049839
# business_stars                                         0.096592
# review_stars                                           0.010240
# business_review_count                                  0.309313
#
#                                          user_compliments_cool  \
# review_cool                                           0.344579
# review_funny                                          0.284697
# review_useful                                         0.308505
# review_votes_count                                    0.330990
# review_length                                         0.219689
# Average_number_of_stars                              -0.004340
# Max_Number_of_stars                                   0.037519
# Min_Number_of_stars                                  -0.082008
# business_review_count                                 0.171153
# user_cool                                             0.850486
# user_funny                                            0.863523
# user_useful                                           0.812921
# user_votes_count                                      0.841810
# user_review_count                                     0.497476
# user_fans                                             0.632782
# user_friends_count                                    0.246876
# user_years_elite_count                                0.312127
# user_compliments_cool                                 1.000000
# user_compliments_cool                                 1.000000
# user_compliments_cute                                 0.750002
# user_compliments_funny                                0.723092
# user_compliments_hot                                  0.988618
# user_compliments_list                                 0.889211
# user_compliments_more                                 0.984040
# user_compliments_note                                 0.914459
# user_compliments_photos                               0.938457
# user_compliments_plain                                0.954016
# user_compliments_profile                              0.967484
# user_compliments_writer                               0.969213
# positive_words_count                                  0.235902
# negative_words_count                                  0.125372
# positive_to_negative_words_count_ratio                0.106546
# negative_to_positive_words_count_ratio                0.000635
# neutral_words_count                                   0.219088
# neutral_words_count_over_review_length                0.028755
# positive_words_count_over_review_length              -0.023333
# negative_words_count_over_review_length              -0.014146
# friends_average_stars                                -0.127614
# user_average_stars                                   -0.006693
# business_stars                                        0.014039
# review_stars                                          0.002909
# business_review_count                                 0.171153
#
#                                                  ...            \
# review_cool                                      ...
# review_funny                                     ...
# review_useful                                    ...
# review_votes_count                               ...
# review_length                                    ...
# Average_number_of_stars                          ...
# Max_Number_of_stars                              ...
# Min_Number_of_stars                              ...
# business_review_count                            ...
# user_cool                                        ...
# user_funny                                       ...
# user_useful                                      ...
# user_votes_count                                 ...
# user_review_count                                ...
# user_fans                                        ...
# user_friends_count                               ...
# user_years_elite_count                           ...
# user_compliments_cool                            ...
# user_compliments_cool                            ...
# user_compliments_cute                            ...
# user_compliments_funny                           ...
# user_compliments_hot                             ...
# user_compliments_list                            ...
# user_compliments_more                            ...
# user_compliments_note                            ...
# user_compliments_photos                          ...
# user_compliments_plain                           ...
# user_compliments_profile                         ...
# user_compliments_writer                          ...
# positive_words_count                             ...
# negative_words_count                             ...
# positive_to_negative_words_count_ratio           ...
# negative_to_positive_words_count_ratio           ...
# neutral_words_count                              ...
# neutral_words_count_over_review_length           ...
# positive_words_count_over_review_length          ...
# negative_words_count_over_review_length          ...
# friends_average_stars                            ...
# user_average_stars                               ...
# business_stars                                   ...
# review_stars                                     ...
# business_review_count                            ...
#
#                                          user_compliments_note  \
# review_cool                                           0.460281
# review_funny                                          0.369216
# review_useful                                         0.434563
# review_votes_count                                    0.448585
# review_length                                         0.262135
# Average_number_of_stars                              -0.003984
# Max_Number_of_stars                                   0.062054
# Min_Number_of_stars                                  -0.120209
# business_review_count                                 0.222637
# user_cool                                             0.907203
# user_funny                                            0.880693
# user_useful                                           0.889490
# user_votes_count                                      0.897571
# user_review_count                                     0.607052
# user_fans                                             0.799599
# user_friends_count                                    0.338033
# user_years_elite_count                                0.420638
# user_compliments_cool                                 0.914459
# user_compliments_cool                                 0.914459
# user_compliments_cute                                 0.856362
# user_compliments_funny                                0.809278
# user_compliments_hot                                  0.922531
# user_compliments_list                                 0.893003
# user_compliments_more                                 0.873564
# user_compliments_note                                 1.000000
# user_compliments_photos                               0.820543
# user_compliments_plain                                0.971797
# user_compliments_profile                              0.854861
# user_compliments_writer                               0.839730
# positive_words_count                                  0.254375
# negative_words_count                                  0.145258
# positive_to_negative_words_count_ratio                0.146256
# negative_to_positive_words_count_ratio                0.006539
# neutral_words_count                                   0.261909
# neutral_words_count_over_review_length                0.049215
# positive_words_count_over_review_length              -0.042060
# negative_words_count_over_review_length              -0.020226
# friends_average_stars                                -0.160547
# user_average_stars                                    0.034885
# business_stars                                        0.022646
# review_stars                                          0.015671
# business_review_count                                 0.222637
#
#                                          user_compliments_photos  \
# review_cool                                             0.218095
# review_funny                                            0.173325
# review_useful                                           0.198768
# review_votes_count                                      0.209039
# review_length                                           0.184791
# Average_number_of_stars                                -0.012195
# Max_Number_of_stars                                     0.018515
# Min_Number_of_stars                                    -0.062848
# business_review_count                                   0.122695
# user_cool                                               0.747540
# user_funny                                              0.766709
# user_useful                                             0.715266
# user_votes_count                                        0.742116
# user_review_count                                       0.467395
# user_fans                                               0.477749
# user_friends_count                                      0.156160
# user_years_elite_count                                  0.180212
# user_compliments_cool                                   0.938457
# user_compliments_cool                                   0.938457
# user_compliments_cute                                   0.585063
# user_compliments_funny                                  0.703041
# user_compliments_hot                                    0.913977
# user_compliments_list                                   0.799381
# user_compliments_more                                   0.953734
# user_compliments_note                                   0.820543
# user_compliments_photos                                 1.000000
# user_compliments_plain                                  0.875234
# user_compliments_profile                                0.962069
# user_compliments_writer                                 0.934178
# positive_words_count                                    0.194191
# negative_words_count                                    0.101019
# positive_to_negative_words_count_ratio                  0.076660
# negative_to_positive_words_count_ratio                 -0.008027
# neutral_words_count                                     0.184387
# neutral_words_count_over_review_length                  0.021206
# positive_words_count_over_review_length                -0.015313
# negative_words_count_over_review_length                -0.013987
# friends_average_stars                                  -0.106198
# user_average_stars                                     -0.022496
# business_stars                                          0.000593
# review_stars                                            0.001821
# business_review_count                                   0.122695
#
#                                          user_compliments_plain  \
# review_cool                                            0.412474
# review_funny                                           0.333361
# review_useful                                          0.390290
# review_votes_count                                     0.403070
# review_length                                          0.233808
# Average_number_of_stars                               -0.012495
# Max_Number_of_stars                                    0.040836
# Min_Number_of_stars                                   -0.103192
# business_review_count                                  0.192502
# user_cool                                              0.904779
# user_funny                                             0.889784
# user_useful                                            0.878924
# user_votes_count                                       0.894489
# user_review_count                                      0.545236
# user_fans                                              0.767576
# user_friends_count                                     0.274092
# user_years_elite_count                                 0.344570
# user_compliments_cool                                  0.954016
# user_compliments_cool                                  0.954016
# user_compliments_cute                                  0.829987
# user_compliments_funny                                 0.731987
# user_compliments_hot                                   0.948693
# user_compliments_list                                  0.917682
# user_compliments_more                                  0.915442
# user_compliments_note                                  0.971797
# user_compliments_photos                                0.875234
# user_compliments_plain                                 1.000000
# user_compliments_profile                               0.906163
# user_compliments_writer                                0.899711
# positive_words_count                                   0.235141
# negative_words_count                                   0.128291
# positive_to_negative_words_count_ratio                 0.130618
# negative_to_positive_words_count_ratio                 0.005323
# neutral_words_count                                    0.233474
# neutral_words_count_over_review_length                 0.039210
# positive_words_count_over_review_length               -0.032815
# negative_words_count_over_review_length               -0.017418
# friends_average_stars                                 -0.145147
# user_average_stars                                     0.019241
# business_stars                                         0.010309
# review_stars                                           0.003104
# business_review_count                                  0.192502
#
#                                          user_compliments_profile  \
# review_cool                                              0.253006
# review_funny                                             0.209818
# review_useful                                            0.225169
# review_votes_count                                       0.242673
# review_length                                            0.158937
# Average_number_of_stars                                 -0.009345
# Max_Number_of_stars                                      0.025322
# Min_Number_of_stars                                     -0.065966
# ...
# user_funny                                                             -0.053546
# user_useful                                                            -0.058958
# user_votes_count                                                       -0.055963
# user_review_count                                                      -0.078368
# user_fans                                                              -0.054783
# user_friends_count                                                     -0.060555
# user_years_elite_count                                                 -0.106155
# user_compliments_cool                                                  -0.023333
# user_compliments_cool                                                  -0.023333
# user_compliments_cute                                                  -0.035117
# user_compliments_funny                                                 -0.032581
# user_compliments_hot                                                   -0.027251
# user_compliments_list                                                  -0.032373
# user_compliments_more                                                  -0.020405
# user_compliments_note                                                  -0.042060
# user_compliments_photos                                                -0.015313
# user_compliments_plain                                                 -0.032815
# user_compliments_profile                                               -0.007937
# user_compliments_writer                                                -0.019179
# positive_words_count                                                    0.168774
# negative_words_count                                                   -0.156296
# positive_to_negative_words_count_ratio                                  0.450678
# negative_to_positive_words_count_ratio                                 -0.324443
# neutral_words_count                                                    -0.154910
# neutral_words_count_over_review_length                                 -0.870168
# positive_words_count_over_review_length                                 1.000000
# negative_words_count_over_review_length                                -0.123172
# friends_average_stars                                                   0.041712
# user_average_stars                                                      0.101439
# business_stars                                                          0.081664
# review_stars                                                            0.242847
# business_review_count                                                  -0.019918
#
#                                          negative_words_count_over_review_length  \
# review_cool                                                            -0.028273
# review_funny                                                            0.029718
# review_useful                                                          -0.018710
# review_votes_count                                                     -0.009238
# review_length                                                          -0.018534
# Average_number_of_stars                                                -0.215034
# Max_Number_of_stars                                                    -0.186619
# Min_Number_of_stars                                                    -0.143262
# business_review_count                                                  -0.045991
# user_cool                                                              -0.022063
# user_funny                                                             -0.013034
# user_useful                                                            -0.020375
# user_votes_count                                                       -0.019244
# user_review_count                                                      -0.032346
# user_fans                                                              -0.016177
# user_friends_count                                                     -0.028501
# user_years_elite_count                                                 -0.028519
# user_compliments_cool                                                  -0.014146
# user_compliments_cool                                                  -0.014146
# user_compliments_cute                                                  -0.024016
# user_compliments_funny                                                 -0.000287
# user_compliments_hot                                                   -0.019098
# user_compliments_list                                                  -0.010049
# user_compliments_more                                                  -0.012342
# user_compliments_note                                                  -0.020226
# user_compliments_photos                                                -0.013987
# user_compliments_plain                                                 -0.017418
# user_compliments_profile                                               -0.008245
# user_compliments_writer                                                -0.008482
# positive_words_count                                                   -0.052247
# negative_words_count                                                    0.421965
# positive_to_negative_words_count_ratio                                 -0.501820
# negative_to_positive_words_count_ratio                                  0.731074
# neutral_words_count                                                    -0.020749
# neutral_words_count_over_review_length                                 -0.381824
# positive_words_count_over_review_length                                -0.123172
# negative_words_count_over_review_length                                 1.000000
# friends_average_stars                                                  -0.033812
# user_average_stars                                                     -0.148441
# business_stars                                                         -0.136879
# review_stars                                                           -0.243775
# business_review_count                                                  -0.045991
#
#                                          friends_average_stars  \
# review_cool                                          -0.152963
# review_funny                                         -0.130840
# review_useful                                        -0.148305
# review_votes_count                                   -0.153045
# review_length                                        -0.089188
# Average_number_of_stars                               0.032144
# Max_Number_of_stars                                   0.006968
# Min_Number_of_stars                                   0.052142
# business_review_count                                -0.066273
# user_cool                                            -0.185319
# user_funny                                           -0.180483
# user_useful                                          -0.196971
# user_votes_count                                     -0.189985
# user_review_count                                    -0.209354
# user_fans                                            -0.180596
# user_friends_count                                   -0.198436
# user_years_elite_count                               -0.199851
# user_compliments_cool                                -0.127614
# user_compliments_cool                                -0.127614
# user_compliments_cute                                -0.123264
# user_compliments_funny                               -0.103124
# user_compliments_hot                                 -0.129899
# user_compliments_list                                -0.156886
# user_compliments_more                                -0.121750
# user_compliments_note                                -0.160547
# user_compliments_photos                              -0.106198
# user_compliments_plain                               -0.145147
# user_compliments_profile                             -0.100522
# user_compliments_writer                              -0.125917
# positive_words_count                                 -0.085591
# negative_words_count                                 -0.075593
# positive_to_negative_words_count_ratio               -0.009726
# negative_to_positive_words_count_ratio               -0.017578
# neutral_words_count                                  -0.088962
# neutral_words_count_over_review_length               -0.022675
# positive_words_count_over_review_length               0.041712
# negative_words_count_over_review_length              -0.033812
# friends_average_stars                                 1.000000
# user_average_stars                                    0.070528
# business_stars                                        0.044509
# review_stars                                          0.016284
# business_review_count                                -0.066273
#
#                                          user_average_stars  business_stars  \
# review_cool                                        0.070254        0.131946
# review_funny                                       0.024403        0.062032
# review_useful                                      0.073928        0.118063
# review_votes_count                                 0.062629        0.113349
# review_length                                      0.024058        0.111711
# Average_number_of_stars                            0.367632        0.618731
# Max_Number_of_stars                                0.353233        0.528571
# Min_Number_of_stars                                0.214197        0.304832
# business_review_count                              0.063584        0.262762
# user_cool                                          0.022600        0.044427
# user_funny                                         0.002368        0.038402
# user_useful                                        0.022457        0.045260
# user_votes_count                                   0.017701        0.043522
# user_review_count                                  0.034451        0.058681
# user_fans                                          0.058185        0.054734
# user_friends_count                                 0.101001        0.063830
# user_years_elite_count                             0.049839        0.096592
# user_compliments_cool                             -0.006693        0.014039
# user_compliments_cool                             -0.006693        0.014039
# user_compliments_cute                              0.034003        0.029092
# user_compliments_funny                             0.018743       -0.019616
# user_compliments_hot                              -0.000096        0.021021
# user_compliments_list                              0.009704        0.028792
# user_compliments_more                             -0.013918        0.011968
# user_compliments_note                              0.034885        0.022646
# user_compliments_photos                           -0.022496        0.000593
# user_compliments_plain                             0.019241        0.010309
# user_compliments_profile                          -0.012103       -0.001159
# user_compliments_writer                           -0.017319        0.021129
# positive_words_count                               0.071759        0.152545
# negative_words_count                              -0.073726       -0.035401
# positive_to_negative_words_count_ratio             0.201292        0.196243
# negative_to_positive_words_count_ratio            -0.160429       -0.184049
# neutral_words_count                                0.023778        0.111495
# neutral_words_count_over_review_length            -0.020766       -0.008090
# positive_words_count_over_review_length            0.101439        0.081664
# negative_words_count_over_review_length           -0.148441       -0.136879
# friends_average_stars                              0.070528        0.044509
# user_average_stars                                 1.000000        0.207753
# business_stars                                     0.207753        1.000000
# review_stars                                       0.396385        0.467635
# business_review_count                              0.063584        0.262762
#
#                                          review_stars  business_review_count
# review_cool                                  0.097869               0.260300
# review_funny                                -0.012682               0.200262
# review_useful                                0.039947               0.242205
# review_votes_count                           0.047020               0.249739
# review_length                                0.013344               0.295686
# Average_number_of_stars                      0.762887               0.158661
# Max_Number_of_stars                          0.657287               0.257470
# Min_Number_of_stars                          0.489759              -0.309002
# business_review_count                        0.119913               1.000000
# user_cool                                    0.015167               0.261979
# user_funny                                   0.008217               0.241647
# user_useful                                  0.012630               0.275296
# user_votes_count                             0.012462               0.263934
# user_review_count                            0.017015               0.306554
# user_fans                                    0.021547               0.289260
# user_friends_count                           0.000252               0.257973
# user_years_elite_count                       0.010240               0.309313
# user_compliments_cool                        0.002909               0.171153
# user_compliments_cool                        0.002909               0.171153
# user_compliments_cute                        0.008649               0.202183
# user_compliments_funny                       0.012390               0.104055
# user_compliments_hot                         0.004892               0.176225
# user_compliments_list                        0.005428               0.223489
# user_compliments_more                        0.006249               0.152090
# user_compliments_note                        0.015671               0.222637
# user_compliments_photos                      0.001821               0.122695
# user_compliments_plain                       0.003104               0.192502
# user_compliments_profile                     0.004043               0.123641
# user_compliments_writer                      0.004727               0.176549
# positive_words_count                         0.127115               0.289852
# negative_words_count                        -0.167725               0.183558
# positive_to_negative_words_count_ratio       0.290528               0.136236
# negative_to_positive_words_count_ratio      -0.320115              -0.030898
# neutral_words_count                          0.012524               0.295253
# neutral_words_count_over_review_length      -0.105127               0.041386
# positive_words_count_over_review_length      0.242847              -0.019918
# negative_words_count_over_review_length     -0.243775              -0.045991
# friends_average_stars                        0.016284              -0.066273
# user_average_stars                           0.396385               0.063584
# business_stars                               0.467635               0.262762
# review_stars                                 1.000000               0.119913
# business_review_count                        0.119913               1.000000
#
# [42 rows x 42 columns]

# %%
import plotly.plotly as py
import plotly.tools as tls
from plotly.graph_objs import *

def triangularize_symmetric_matrix(x, y, z):
    x_new = x[0:-1]
    y_new = y[-1:0:-1]
    tmp = np.empty(z.shape)
    tmp.fill(np.nan)
    for i in range(len(z)):
        tmp[i, 0 :i] = z[i, 0:i]
    tmp = np.flipud(tmp)
    z_new = tmp
    return (x_new, y_new, z_new)

# %%
py.sign_in('kevin11h', 'ilrcfqwrng')

(x, y, z) = triangularize_symmetric_matrix(corr_features,
                                           corr_features,
                                           Corr_df.as_matrix())

trace = Heatmap(z=z,
                x=x,
                y=y,
                zauto=False,
                zmax = 1,
                zmin = -1,
                colorscale=[[-1,'#3333CC'], [0, '#CC00CC'], [1, '#CC0000']],
                reversescale=True,
                colorbar=ColorBar(titleside='bottom',
                                  title='   %f'%-1))

data = Data([trace])

title = 'Feature Correlations of Yelp Reviews'


layout = Layout(title=title,
                autosize=False,
                height=500,
                width=600,
                annotations=Annotations([Annotation(text=annotation_text,
                                         xref='paper',
                                         yref='paper',
                                         xanchor='right',
                                         yanchor='bottom',
                                         x=.75,
                                         y=1)])
                )
axis_style = {'autotick':False,'showgrid':False,'showline':False}
layout.update(xaxis=XAxis(axis_style, tickangle=90))
layout.update(yaxis=YAxis(axis_style))

fig = Figure(data=data, layout=layout)

url = py.plot(fig, filename='yelp_feature_correlations', auto_open=False)
print url
py.iplot(fig, filename='yelp_feature_correlations')
# Out:
# https://plot.ly/~kevin11h/25
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~kevin11h/25.embed" height="500px" width="600px"></iframe>
